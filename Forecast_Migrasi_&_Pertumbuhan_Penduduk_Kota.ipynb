# %% [markdown]
# <a href="https://colab.research.google.com/github/windyrahayu45/ML-PadangPanjang/blob/main/Forecast_Migrasi_%26_Pertumbuhan_Penduduk_Kota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# 1) Load data final (yang sama dipakai untuk use case lain)
df = pd.read_csv("dtsen_with_scores.csv")

# 2) Populasi baseline per kelurahan (estimasi dari data rumah tangga)
pop_base = (
    df.groupby("kelurahan")["jumlah_anggota_keluarga"]
      .sum()
      .rename("pop_base")
      .reset_index()
)

kelurahan_list = pop_base["kelurahan"].tolist()

# 3) Bangun rentang waktu bulanan 2019-01 s/d 2025-09 (atau sesuaikan)
dates = pd.date_range(start="2019-01-01", end="2025-09-01", freq="MS")

# 4) Skenario growth & migrasi sintetis per kelurahan
rows = []
rng = np.random.default_rng(42)
for _, r in pop_base.iterrows():
    kel = r["kelurahan"]
    base = r["pop_base"]
    # growth tahunan 0.2%–1.5%, noise musiman ringan
    annual_growth = rng.uniform(0.002, 0.015)
    monthly_growth = (1 + annual_growth) ** (1/12) - 1
    # komponenn migrasi bulanan random kecil (-0.25% s/d 0.25%)
    mig_sigma = 0.0025

    level = base * 0.9  # start a bit lower in 2019
    for i, d in enumerate(dates):
        # seasonality sederhana: puncak pertengahan tahun
        season = 1.0 + 0.003*np.sin(2*np.pi*(d.month/12))
        # migrasi acak
        migration = rng.normal(0, mig_sigma)
        level = level * (1 + monthly_growth) * season * (1 + migration)
        rows.append({"date": d, "kelurahan": kel, "population": max(level, 10)})

ts = pd.DataFrame(rows)

# 5) Tambahkan metrik migrasi sintetis (inflow/outflow) agar bisa dianalisis
# (sekadar proporsi kecil dari populasi + noise)
ts["mig_in"]  = (ts["population"] * 0.003 * (1 + rng.normal(0, 0.2, len(ts)))).clip(lower=0).round()
ts["mig_out"] = (ts["population"] * 0.0025 * (1 + rng.normal(0, 0.2, len(ts)))).clip(lower=0).round()

# 6) Simpan time-series sintetis (untuk referensi & reproducibility)
ts.to_csv("ts_penduduk_kelurahan_2019_2025.csv", index=False)
print("✅ Saved ts_penduduk_kelurahan_2019_2025.csv")
# Out:
# ✅ Saved ts_penduduk_kelurahan_2019_2025.csv

# %%
# !pip install prophet
from prophet import Prophet

def forecast_kelurahan_prophet(ts_df, kelurahan, horizon_months=60):
    df_k = ts_df[ts_df["kelurahan"] == kelurahan][["date","population"]].copy()
    df_k.columns = ["ds","y"]  # Prophet needs ds, y

    m = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        seasonality_mode="additive",
        interval_width=0.9
    )
    m.fit(df_k)

    future = m.make_future_dataframe(periods=horizon_months, freq="MS")
    fcst  = m.predict(future)
    fcst["kelurahan"] = kelurahan
    return fcst[["ds","kelurahan","yhat","yhat_lower","yhat_upper"]]

# Forecast semua kelurahan
all_fcst = []
for kel in kelurahan_list:
    fc = forecast_kelurahan_prophet(ts, kel, horizon_months=60)
    all_fcst.append(fc)
fcst_prophet = pd.concat(all_fcst, ignore_index=True)

# Simpan
fcst_prophet.to_csv("forecast_penduduk_prophet_5y.csv", index=False)
print("✅ Saved forecast_penduduk_prophet_5y.csv")
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/cmcs8z6p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/deynkys3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59527', 'data', 'file=/tmp/tmpm9a8dfvt/cmcs8z6p.json', 'init=/tmp/tmpm9a8dfvt/deynkys3.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelebpqg8m7/prophet_model-20250919160347.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/o52pm8bw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/lh6qsobs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36782', 'data', 'file=/tmp/tmpm9a8dfvt/o52pm8bw.json', 'init=/tmp/tmpm9a8dfvt/lh6qsobs.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelucjbe8wx/prophet_model-20250919160348.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/qco5deu2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/u1rsokp6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28979', 'data', 'file=/tmp/tmpm9a8dfvt/qco5deu2.json', 'init=/tmp/tmpm9a8dfvt/u1rsokp6.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modeliot1elz6/prophet_model-20250919160349.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/amw_6e8t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/n27yxgxl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1622', 'data', 'file=/tmp/tmpm9a8dfvt/amw_6e8t.json', 'init=/tmp/tmpm9a8dfvt/n27yxgxl.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelmzf6x22e/prophet_model-20250919160349.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/k_zmmq_w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/es0bw_e9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94947', 'data', 'file=/tmp/tmpm9a8dfvt/k_zmmq_w.json', 'init=/tmp/tmpm9a8dfvt/es0bw_e9.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelkb3c8fgj/prophet_model-20250919160350.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/900so5dy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/6rjcga2o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28602', 'data', 'file=/tmp/tmpm9a8dfvt/900so5dy.json', 'init=/tmp/tmpm9a8dfvt/6rjcga2o.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modeliqkmh2jf/prophet_model-20250919160350.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/49cnmmxl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/91rquep5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69831', 'data', 'file=/tmp/tmpm9a8dfvt/49cnmmxl.json', 'init=/tmp/tmpm9a8dfvt/91rquep5.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelaflkkh9o/prophet_model-20250919160350.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/zqgnxsyh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/r1945hbh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77161', 'data', 'file=/tmp/tmpm9a8dfvt/zqgnxsyh.json', 'init=/tmp/tmpm9a8dfvt/r1945hbh.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelbmhevqd1/prophet_model-20250919160351.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/90o_on75.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/jbwpk9_p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91108', 'data', 'file=/tmp/tmpm9a8dfvt/90o_on75.json', 'init=/tmp/tmpm9a8dfvt/jbwpk9_p.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelok13_eyg/prophet_model-20250919160351.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/plleh7j7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/t9q_1xtv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70613', 'data', 'file=/tmp/tmpm9a8dfvt/plleh7j7.json', 'init=/tmp/tmpm9a8dfvt/t9q_1xtv.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelcrg631cu/prophet_model-20250919160352.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/_cm84gop.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/e0498104.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74159', 'data', 'file=/tmp/tmpm9a8dfvt/_cm84gop.json', 'init=/tmp/tmpm9a8dfvt/e0498104.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_models8en68b1/prophet_model-20250919160352.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/vcnb81ll.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/2w01go7e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41543', 'data', 'file=/tmp/tmpm9a8dfvt/vcnb81ll.json', 'init=/tmp/tmpm9a8dfvt/2w01go7e.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_model3g06fr11/prophet_model-20250919160353.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/d7t_uj0d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/ukesuhbw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17661', 'data', 'file=/tmp/tmpm9a8dfvt/d7t_uj0d.json', 'init=/tmp/tmpm9a8dfvt/ukesuhbw.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_model1t0xwxrn/prophet_model-20250919160353.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/n1frcrja.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/cxwac3e9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93414', 'data', 'file=/tmp/tmpm9a8dfvt/n1frcrja.json', 'init=/tmp/tmpm9a8dfvt/cxwac3e9.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modeluyd6klpq/prophet_model-20250919160354.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/ktqom4w0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/3o32333u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41943', 'data', 'file=/tmp/tmpm9a8dfvt/ktqom4w0.json', 'init=/tmp/tmpm9a8dfvt/3o32333u.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelluh_6tvl/prophet_model-20250919160354.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/njd04_mi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm9a8dfvt/m20n0p3t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81588', 'data', 'file=/tmp/tmpm9a8dfvt/njd04_mi.json', 'init=/tmp/tmpm9a8dfvt/m20n0p3t.json', 'output', 'file=/tmp/tmpm9a8dfvt/prophet_modelgucu_fmd/prophet_model-20250919160354.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:03:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:03:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ✅ Saved forecast_penduduk_prophet_5y.csv

# %%
# Pilih salah satu output forecast (Prophet atau SARIMAX)
fcst = pd.read_csv("forecast_penduduk_prophet_5y.csv")  # atau '...sarimax_5y.csv'
hist = pd.read_csv("ts_penduduk_kelurahan_2019_2025.csv")

# Agregasi bulanan per kota
hist_city = hist.groupby("date")["population"].sum().reset_index(name="population")
fcst_city = fcst.groupby("ds")["yhat"].sum().reset_index(name="yhat")

# Simpan untuk Streamlit
hist_city.rename(columns={"date":"period"}, inplace=True)
fcst_city.rename(columns={"ds":"period"}, inplace=True)

hist_city.to_csv("hist_penduduk_kota.csv", index=False)
fcst_city.to_csv("forecast_penduduk_kota_5y.csv", index=False)
print("✅ Saved hist_penduduk_kota.csv & forecast_penduduk_kota_5y.csv")
# Out:
# ✅ Saved hist_penduduk_kota.csv & forecast_penduduk_kota_5y.csv
